# %% [markdown]
# # Data collection - Wikipeople

# %%
from wikipeople import wikipeople as wp
import pandas as pd
import json
import re

# %% [markdown]
# ## Retrieve the data on Wikipeople

# %%
def get_guest_info(guest):
    wiki_info = {}
    search_results = None
    try:
      search_results = wp.search_wikidata(guest)
    except Exception:
      wiki_info['gender'] = None
      wiki_info['career'] = None
      wiki_info['birth'] = None
      wiki_info['country'] = None
    
    if search_results:
        wikidata_id = search_results
        wiki_info['gender'] = wp.get_property(wikidata_id, 'P21')[1]
        wiki_info['career'] = wp.get_property(wikidata_id, 'P106')[1]
        wiki_info['birth'] = wp.get_date_of_birth(wikidata_id)
        wiki_info['country'] = wp.get_property(wikidata_id, 'P27')[1]

    
    return wiki_info

# %%
df = pd.read_csv("Guests.csv", index_col='Unnamed: 0')

# %%
def clean_guest_name(name_list):
    clean_list = []
    for name in name_list:
        # Only keep the text before the first comma
        name = name.split(',')[0].strip()
        # Remove specific prefixes
        prefixes = ["Dr ", "Rt Hon ", "Rt Hon. ", "Sir ", "Prof ", "Professor ", "Commander ", "Commissioner ", "Desert Island Discs"]
        for prefix in prefixes:
            name = name.replace(prefix, "")
        # Remove numbers
        name = re.sub(r'\d+', '', name)
        # Replace "-" with " "
        name = name.replace("-", " ")
        # Remove "(" and ")"
        name = name.replace("(", "").replace(")", "").replace("/", "")
        # Trim leading and trailing whitespace
        name = name.strip()
        
        clean_list.append(name)
    
    return clean_list

# %%
df['name'] = clean_guest_name(df['guests'])
df
# Out:
#             time    duration book luxury favourite  availibility  number  \
# 0     2023-06-04  42 minutes  NaN    NaN       NaN         False       0
# 1     2023-05-28  35 minutes  NaN    NaN       NaN         False       0
# 2     2023-05-26  43 minutes  NaN    NaN       NaN         False       8
# 3     2023-05-19  44 minutes  NaN    NaN       NaN         False       8
# 4     2023-05-12  37 minutes  NaN    NaN       NaN         False       8
# ...          ...         ...  ...    ...       ...           ...     ...
# 3355  1942-02-26  30 minutes  NaN    NaN       NaN         False       7
# 3356  1942-02-19  30 minutes  NaN    NaN       NaN         False       8
# 3357  1942-02-12  30 minutes  NaN    NaN       NaN         False       8
# 3358  1942-02-05  30 minutes  NaN    NaN       NaN         False       7
# 3359  1942-01-29  30 minutes  NaN    NaN       NaN         False       7
#
#                                                  guests  \
# 0                                            04/06/2023
# 1                     Ronnie O'Sullivan, snooker player
# 2     Desert Island Discs - Professor Sharon Peacock...
# 3                                     Simon Pegg, actor
# 4                   Professor Peter Hennessy, historian
# ...                                                 ...
# 3355                                       Pat Kirkwood
# 3356                                        C B Cochran
# 3357                                 Commander Campbell
# 3358                                        James Agate
# 3359                                         Vic Oliver
#
#                                           links  index  year  \
# 0     https://www.bbc.co.uk/programmes/m001mly1      0  2023
# 1     https://www.bbc.co.uk/programmes/m001mc30      1  2023
# 2     https://www.bbc.co.uk/programmes/m001m4nx      2  2023
# 3     https://www.bbc.co.uk/programmes/m001ly7j      3  2023
# 4     https://www.bbc.co.uk/programmes/m001lr3k      4  2023
# ...                                         ...    ...   ...
# 3355  https://www.bbc.co.uk/programmes/p009y0n8   3355  1942
# 3356  https://www.bbc.co.uk/programmes/p009y0nd   3356  1942
# 3357  https://www.bbc.co.uk/programmes/p009y0nh   3357  1942
# 3358  https://www.bbc.co.uk/programmes/p009y0nl   3358  1942
# 3359  https://www.bbc.co.uk/programmes/p009y0nq   3359  1942
#
#                    name
# 0
# 1     Ronnie O'Sullivan
# 2        Sharon Peacock
# 3            Simon Pegg
# 4        Peter Hennessy
# ...                 ...
# 3355       Pat Kirkwood
# 3356        C B Cochran
# 3357           Campbell
# 3358        James Agate
# 3359         Vic Oliver
#
# [3360 rows x 12 columns]

# %%
data_generator = ((row['name'], row['index']) for _, row in df.iloc[:5, :].iterrows())

with open('wiki_data.json', 'w') as file:
    for i, (guest, index) in enumerate(data_generator):
        print(f"Processing {guest}")

        data = {'guests': guest, 'index': index}
        info = get_guest_info(guest)
        data.update(info)
        
        json_data = json.dumps(data)
        file.write(json_data)
        file.write('\n')
        print(f"Data {index} written to file")
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Processing Carl Djerassi
# Data 860 written to file
# Processing Paul Gambaccini
# Data 861 written to file
# Processing Philip Pullman
# Data 862 written to file
# Processing Dame Alicia Markova
# Data 863 written to file
# Processing Timothy Spall
# Data 864 written to file
# Processing Brian May
# Data 865 written to file
# Processing Alan Titchmarsh
# Data 866 written to file
# Processing Minette Walters
# Data 867 written to file
# Processing Countess Elizabeth Longford
# Data 868 written to file
# Processing Jan Morris
# Data 869 written to file
# Processing Leonard Rosoman
# Data 870 written to file
# Processing Sue Johnston
# Data 871 written to file
# Processing Suggs
# Data 872 written to file
# Processing Aaron Klug
# Data 873 written to file
# Processing Jude Kelly
# Data 874 written to file
# Processing Betty Jackson
# Data 875 written to file
# Processing Wayne Marshall
# Data 876 written to file
# Processing Christopher Bland
# Data 877 written to file
# Processing Fiona Reynolds
# Data 878 written to file
# Processing Gordon Ramsay
# Data 879 written to file
# Processing Dorothy Rowe
# Data 880 written to file
# Processing Fay Godwin
# Data 881 written to file
# Processing Dame Beryl Grey
# Data 882 written to file
# Processing Lord May
# Data 883 written to file
# Processing Sue MacGregor
# Data 884 written to file
# Processing Kazuo Ishiguro
# Data 885 written to file
# Processing Paul Nurse
# Data 886 written to file
# Processing David Linley
# Data 887 written to file
# Processing Phyllis Sellick
# Data 888 written to file
# Processing Bob Worcester
# Data 889 written to file
# Processing Susana Walton
# Data 890 written to file
# Processing Peter Morris
# Data 891 written to file
# Processing Ewan McGregor
# Data 892 written to file
# Processing Jamie Oliver
# Data 893 written to file
# Processing Anne Fine
# Data 894 written to file
# Processing Cameron Mackintosh
# Data 895 written to file
# Processing William Hague MP
# Data 896 written to file
# Processing Ken Follett
# Data 897 written to file
# Processing Billy Connolly
# Data 898 written to file
# Processing Simon Schama
# Data 899 written to file
# Processing Lord Roll
# Data 900 written to file
# Processing Bruce Fogle
# Data 901 written to file
# Processing Joss Ackland
# Data 902 written to file
# Processing Lord Deedes
# Data 903 written to file
# Processing Claudia Roden
# Data 904 written to file
# Processing Cormac Murphy O'Connor
# Data 905 written to file
# Processing Martin Bell
# Data 906 written to file
# Processing Peggy Seeger
# Data 907 written to file
# Processing Stanley Kalms
# Data 908 written to file
# Processing Harry Kroto
# Data 909 written to file
# Processing Frank McCourt
# Data 910 written to file
# Processing Kyffin Williams
# Data 911 written to file
# Processing Thomas Allen
# Data 912 written to file
# Processing Courtney Pine
# Data 913 written to file
# Processing Timothy Clifford
# Data 914 written to file
# Processing John Sulston
# Data 915 written to file
# Processing Margaret Drabble
# Data 916 written to file
# Processing Tasmin Little
# Data 917 written to file
# Processing Chris Tarrant
# Data 918 written to file
# Processing Ronald Blythe
# Data 919 written to file
# Processing Tanni Grey Thompson
# Data 920 written to file
# Processing Alec Broers
# Data 921 written to file
# Processing Shirley Hughes
# Data 922 written to file
# Processing Peter Vanezis
# Data 923 written to file
# Processing Henry Sandon
# Data 924 written to file
# Processing John Lill
# Data 925 written to file
# Processing Charlie Watts
# Data 926 written to file
# Processing Richard Doll
# Data 927 written to file
# Processing Griff Rhys Jones
# Data 928 written to file
# Processing John Mortimer
# Data 929 written to file
# Processing Terry O'Neill
# Data 930 written to file
# Processing Marguerite Patten
# Data 931 written to file
# Processing George MacDonald Fraser
# Data 932 written to file
# Processing Marquess Of Bath
# Data 933 written to file
# Processing Stephen Sondheim
# Data 934 written to file
# Processing Norman Painting
# Data 935 written to file
# Processing Jocelyn Bell Burnell
# Data 936 written to file
# Processing Richard Briers
# Data 937 written to file
# Processing Tim Smit
# Data 938 written to file
# Processing Tina Brown
# Data 939 written to file
# Processing Albie Sachs
# Data 940 written to file
# Processing Des Lynam
# Data 941 written to file
# Processing J K Rowling
# Data 942 written to file
# Processing Ronald Harwood
# Data 943 written to file
# Processing Christopher Lloyd
# Data 944 written to file
# Processing Robert Swan
# Data 945 written to file
# Processing Norman Wisdom
# Data 946 written to file
# Processing General Charles Guthrie
# Data 947 written to file
# Processing Roger Penrose
# Data 948 written to file
# Processing Michael Portillo MP
# Data 949 written to file
# Processing Alan Parker
# Data 950 written to file
# Processing Peter Nichols
# Data 951 written to file
# Processing Max Perutz
# Data 952 written to file
# Processing Donald Sutherland
# Data 953 written to file
# Processing Clive James
# Data 954 written to file
# Processing Géza Vermes
# Data 955 written to file
# Processing John Bird
# Data 956 written to file
# Processing Dame Norma Major
# Data 957 written to file
# Processing Kathleen Turner
# Data 958 written to file
# Processing John Mills
# Data 959 written to file
# Processing Peter Bonfield
# Data 960 written to file
# Processing Leonard Slatkin
# Data 961 written to file
# Processing Anthony Caro
# Data 962 written to file
# Processing Claire Tomalin
# Data 963 written to file
# Processing Harold Evans
# Data 964 written to file
# Processing Adrian Noble
# Data 965 written to file
# Processing Al Alvarez
# Data 966 written to file
# Processing Colin Montgomerie
# Data 967 written to file
# Processing Robert McCrum
# Data 968 written to file
# Processing Sheila Hancock
# Data 969 written to file
# Processing Michael Holroyd
# Data 970 written to file
# Processing Stuart Hall
# Data 971 written to file
# Processing Simon Callow
# Data 972 written to file
# Processing Peter Melchett
# Data 973 written to file
# Processing Neil Jordan
# Data 974 written to file
# Processing Ian McEwan
# Data 975 written to file
# Processing Jane Goodall
# Data 976 written to file
# Processing Andrew Lloyd Webber
# Data 977 written to file
# Processing Michael Crawford
# Data 978 written to file
# Processing Michael Nyman
# Data 979 written to file
# Processing Oz Clarke
# Data 980 written to file
# Processing Richard Sykes
# Data 981 written to file
# Processing Warren Mitchell
# Data 982 written to file
# Processing Clarissa Dickson Wright
# Data 983 written to file
# Processing William Gibson
# Data 984 written to file
# Processing Willard White
# Data 985 written to file
# Processing Ralph Fiennes
# Data 986 written to file
# Processing Rolf Harris
# Data 987 written to file
# Processing Rita Dove
# Data 988 written to file
# Processing Roger Norrington
# Data 989 written to file
# Processing Patricia Routledge
# Data 990 written to file
# Processing Rick Stein
# Data 991 written to file
# Processing Rod Steiger
# Data 992 written to file
# Processing Martin Pipe
# Data 993 written to file
# Processing Paddy Moloney
# Data 994 written to file
# Processing Igor Aleksander
# Data 995 written to file
# Processing Ann Widdecombe MP
# Data 996 written to file
# Processing James Dyson
# Data 997 written to file
# Processing John Barry
# Data 998 written to file
# Processing Chris Bonington
# Data 999 written to file
# Processing Anthony Howard
# Data 1000 written to file
# Processing Christopher Bruce
# Data 1001 written to file
# Processing Michael Green
# Data 1002 written to file
# Processing Richard Dreyfuss
# Data 1003 written to file
# Processing Helen Bamber
# Data 1004 written to file
# Processing Stan Tracey
# Data 1005 written to file
# Processing Ken Loach
# Data 1006 written to file
# Processing Paco Peña
# Data 1007 written to file
# Processing Richard Dunwoody
# Data 1008 written to file
# Processing Luise Rainer
# Data 1009 written to file
# Processing Mo Mowlam MP
# Data 1010 written to file
# Processing Fay Maschler
# Data 1011 written to file
# Processing Charles Mackerras
# Data 1012 written to file
# Processing Richard Curtis
# Data 1013 written to file
# Processing Maria Ewing
# Data 1014 written to file
# Processing Nina Cassian
# Data 1015 written to file
# Processing Andras Schiff
# Data 1016 written to file
# Processing Bill Bryson
# Data 1017 written to file
# Processing Ruth Prawer Jhabvala
# Data 1018 written to file
# Processing David Shepherd
# Data 1019 written to file
# Processing Clare Hollingworth
# Data 1020 written to file
# Processing Dave Brubeck
# Data 1021 written to file
# Processing David Attenborough
# Data 1022 written to file
# Processing Bob Monkhouse
# Data 1023 written to file
# Processing Dick Francis
# Data 1024 written to file
# Processing John Keegan
# Data 1025 written to file
# Processing Eileen Atkins
# Data 1026 written to file
# Processing Bill Morris
# Data 1027 written to file
# Processing Nicole Kidman
# Data 1028 written to file
# Processing Joseph Rotblat
# Data 1029 written to file
# Processing Paul Daniel
# Data 1030 written to file
# Processing Lucy Gannon
# Data 1031 written to file
# Processing Ralph Koltai
# Data 1032 written to file
# Processing Les Murray
# Data 1033 written to file
# Processing David Hempleman Adams
# Data 1034 written to file
# Processing Ralph Steadman
# Data 1035 written to file
# Processing Chris De Burgh
# Data 1036 written to file
# Processing Howard Brenton
# Data 1037 written to file
# Processing Jack Straw MP
# Data 1038 written to file
# Processing Sybille Bedford
# Data 1039 written to file
# Processing Jack Rosenthal
# Data 1040 written to file
# Processing John Bird
# Data 1041 written to file
# Processing Bill Kenwright
# Data 1042 written to file
# Processing Geoffrey Smith
# Data 1043 written to file
# Processing John Harle
# Data 1044 written to file
# Processing David Willcocks
# Data 1045 written to file
# Processing Antony Gormley
# Data 1046 written to file
# Processing Susan Blackmore
# Data 1047 written to file
# Processing Ernest Hall
# Data 1048 written to file
# Processing Terry Frost
# Data 1049 written to file
# Processing Judi Dench
# Data 1050 written to file
# Processing Gavin Bryars
# Data 1051 written to file
# Processing Alice Thomas Ellis
# Data 1052 written to file
# Processing Andrew Motion
# Data 1053 written to file
# Processing Ian Stewart
# Data 1054 written to file
# Processing Anthony Dowell
# Data 1055 written to file
# Processing Archie Norman MP
# Data 1056 written to file
# Processing David Pountney
# Data 1057 written to file
# Processing Richard Noble
# Data 1058 written to file
# Processing Colin Dexter
# Data 1059 written to file
# Processing Helena Kennedy QC
# Data 1060 written to file
# Processing John Tomlinson
# Data 1061 written to file
# Processing Paul Hogarth
# Data 1062 written to file
# Processing Heinz Wolff
# Data 1063 written to file
# Processing Glenda Jackson MP
# Data 1064 written to file
# Processing Harry Secombe
# Data 1065 written to file
# Processing Chris Haskins
# Data 1066 written to file
# Processing Paula Rego
# Data 1067 written to file
# Processing Loyd Grossman
# Data 1068 written to file
# Processing Thelma Holt
# Data 1069 written to file
# Processing Anthony Minghella
# Data 1070 written to file
# Processing John Julius Norwich
# Data 1071 written to file
# Processing Richard Mabey
# Data 1072 written to file
# Processing Richard Rodney Bennett
# Data 1073 written to file
# Processing Rose Tremain
# Data 1074 written to file
# Processing Jools Holland
# Data 1075 written to file
# Processing Peter O'Sullevan
# Data 1076 written to file
# Processing Mike Leigh OBE
# Data 1077 written to file
# Processing Ursula Owen
# Data 1078 written to file
# Processing Frank Kermode
# Data 1079 written to file
# Processing Cleo Laine
# Data 1080 written to file
# Processing Iain Banks
# Data 1081 written to file
# Processing Eric Sykes
# Data 1082 written to file
# Processing Christina Noble
# Data 1083 written to file
# Processing Benjamin Zephaniah
# Data 1084 written to file
# Processing Joanna MacGregor
# Data 1085 written to file
# Processing Sian Phillips
# Data 1086 written to file
# Processing Harry Enfield
# Data 1087 written to file
# Processing David Wynne
# Data 1088 written to file
# Processing Martin Rees
# Data 1089 written to file
# Processing Andy Hamilton
# Data 1090 written to file
# Processing Saeed Jaffrey
# Data 1091 written to file
# Processing Virginia Ironside
# Data 1092 written to file
# Processing Peter Blake
# Data 1093 written to file
# Processing Nina Campbell
# Data 1094 written to file
# Processing Redmond O'Hanlon
# Data 1095 written to file
# Processing Susan Greenfield
# Data 1096 written to file
# Processing Nico Ladenis
# Data 1097 written to file
# Processing Mary Benson
# Data 1098 written to file
# Processing Terry Pratchett
# Data 1099 written to file
# Processing Gene Wilder
# Data 1100 written to file
# Processing Irene Thomas
# Data 1101 written to file
# Processing John Cleese
# Data 1102 written to file
# Processing Martin Amis
# Data 1103 written to file
# Processing Jennifer Saunders
# Data 1104 written to file
# Processing Ian Dury
# Data 1105 written to file
# Processing Robert Winston
# Data 1106 written to file
# Processing Bruce Forsyth
# Data 1107 written to file
# Processing Tony Blair MP
# Data 1108 written to file
# Processing Tessa Sanderson
# Data 1109 written to file
# Processing Laurens Van Der Post
# Data 1110 written to file
# Processing Chris Patten
# Data 1111 written to file
# Processing Jancis Robinson
# Data 1112 written to file
# Processing Jackie Charlton
# Data 1113 written to file
# Processing Rumer Godden
# Data 1114 written to file
# Processing Lewis Wolpert
# Data 1115 written to file
# Processing Ben Elton
# Data 1116 written to file
# Processing Fran Landesman
# Data 1117 written to file
# Processing Kevin Whately
# Data 1118 written to file
# Processing Colin Blakemore
# Data 1119 written to file
# Processing Terence Conran
# Data 1120 written to file
# Processing Anita Lasker Wallfisch
# Data 1121 written to file
# Processing André Previn
# Data 1122 written to file
# Processing Quentin Crewe
# Data 1123 written to file
# Processing Peggy Mount
# Data 1124 written to file
# Processing Gerry Robinson
# Data 1125 written to file
# Processing Michael White
# Data 1126 written to file
# Processing Janet Holmes à Court
# Data 1127 written to file
# Processing Hugh Laurie
# Data 1128 written to file
# Processing Pauline Quirke
# Data 1129 written to file
# Processing Mitsuko Uchida
# Data 1130 written to file
# Processing Hanif Kureishi
# Data 1131 written to file
# Processing Viscount Rothermere
# Data 1132 written to file
# Processing Dickie Bird
# Data 1133 written to file
# Processing Simon Weston
# Data 1134 written to file
# Processing Kyra Vayne
# Data 1135 written to file
# Processing Lord Alexander
# Data 1136 written to file
# Processing Gordon Brown MP
# Data 1137 written to file
# Processing Roy Calne
# Data 1138 written to file
# Processing George Steiner
# Data 1139 written to file
# Processing Susan Hill
# Data 1140 written to file
# Processing Eve Arnold
# Data 1141 written to file
# Processing Julian Barnes
# Data 1142 written to file
# Processing Chili Bouchier
# Data 1143 written to file
# Processing Jimmy McGovern
# Data 1144 written to file
# Processing Christopher Hampton
# Data 1145 written to file
# Processing Lady Margaret Tebbit
# Data 1146 written to file
# Processing Petula Clark
# Data 1147 written to file
# Processing Barbara Dickson
# Data 1148 written to file
# Processing Alison Steadman
# Data 1149 written to file
# Processing George Martin
# Data 1150 written to file
# Processing Umberto Eco
# Data 1151 written to file
# Processing Gillian Shephard MP
# Data 1152 written to file
# Processing Elizabeth Jane Howard
# Data 1153 written to file
# Processing Don Black
# Data 1154 written to file
# Processing Richard Hoggart
# Data 1155 written to file
# Processing Alan Yentob
# Data 1156 written to file
# Processing Jenny Pitman
# Data 1157 written to file
# Processing Maurice Saatchi
# Data 1158 written to file
# Processing Max Nicholson
# Data 1159 written to file
# Processing John Updike
# Data 1160 written to file
# Processing Wendy Richard
# Data 1161 written to file
# Processing Duke Of Westminster
# Data 1162 written to file
# Processing Jasper Conran
# Data 1163 written to file
# Processing Magdi Yacoub
# Data 1164 written to file
# Processing John Lee Hooker
# Data 1165 written to file
# Processing Brian Blessed
# Data 1166 written to file
# Processing Marianne Faithfull
# Data 1167 written to file
# Processing Bernard Ingham
# Data 1168 written to file
# Processing Neil Simon
# Data 1169 written to file
# Processing George Carey
# Data 1170 written to file
# Processing Pete Waterman
# Data 1171 written to file
# Processing George Lloyd
# Data 1172 written to file
# Processing Hugh Grant
# Data 1173 written to file
# Processing James Bowman
# Data 1174 written to file
# Processing Nina Bawden
# Data 1175 written to file
# Processing Felix Aprahamian
# Data 1176 written to file
# Processing Nigel Nicolson
# Data 1177 written to file
# Processing Eric Hobsbawm
# Data 1178 written to file
# Processing Christopher Lee
# Data 1179 written to file
# Processing Jimmy Knapp
# Data 1180 written to file
# Processing Adrian Cadbury
# Data 1181 written to file
# Processing Richard Dawkins
# Data 1182 written to file
# Processing Phil Redmond
# Data 1183 written to file
# Processing Patricia Hodge
# Data 1184 written to file
# Processing Alan Clark
# Data 1185 written to file
# Processing David Jason OBE
# Data 1186 written to file
# Processing Penelope Hobhouse
# Data 1187 written to file
# Processing Margaret Forster
# Data 1188 written to file
# Processing Howard Hodgkin
# Data 1189 written to file
# Processing Glenys Kinnock
# Data 1190 written to file
# Processing Berthold Goldschmidt
# Data 1191 written to file
# Processing Archbishop Desmond Tutu
# Data 1192 written to file
# Processing Kathleen Hale
# Data 1193 written to file
# Processing Lynda La Plante
# Data 1194 written to file
# Processing George Christie
# Data 1195 written to file
# Processing Jeanette Winterson
# Data 1196 written to file
# Processing James Fenton
# Data 1197 written to file
# Processing Mary Stott
# Data 1198 written to file
# Processing John Tavener
# Data 1199 written to file
# Processing Joanna Trollope
# Data 1200 written to file
# Processing Rabbi Hugo Gryn
# Data 1201 written to file
# Processing Derek Jameson
# Data 1202 written to file
# Processing John Drummond
# Data 1203 written to file
# Processing Brian Sewell
# Data 1204 written to file
# Processing Zoe Wanamaker
# Data 1205 written to file
# Processing Milton Shulman
# Data 1206 written to file
# Processing Peter Scudamore
# Data 1207 written to file
# Processing Britt Ekland
# Data 1208 written to file
# Processing Kate Adie
# Data 1209 written to file
# Processing John Wilson
# Data 1210 written to file
# Processing Garrison Keillor
# Data 1211 written to file
# Processing Trevor McDonald
# Data 1212 written to file
# Processing Alan Hacker
# Data 1213 written to file
# Processing Roger McGough
# Data 1214 written to file
# Processing Ranulph Fiennes
# Data 1215 written to file
# Processing Conrad Black
# Data 1216 written to file
# Processing Christina Dodwell
# Data 1217 written to file
# Processing Frances Partridge
# Data 1218 written to file
# Processing Kenneth Clarke MP
# Data 1219 written to file
# Processing Rosemary Verey
# Data 1220 written to file
# Processing Douglas Adams
# Data 1221 written to file
# Processing Dame Cicely Saunders
# Data 1222 written to file
# Processing Willy Russell
# Data 1223 written to file
# Processing Harrison Birtwistle
# Data 1224 written to file
# Processing Ian Hislop
# Data 1225 written to file
# Processing Oliver Sacks
# Data 1226 written to file
# Processing Lord Ashley
# Data 1227 written to file
# Processing Phil Collins
# Data 1228 written to file
# Processing Taki
# Data 1229 written to file
# Processing Doris Lessing
# Data 1230 written to file
# Processing Shirley Anne Field
# Data 1231 written to file
# Processing Sybil Marshall
# Data 1232 written to file
# Processing Judge Stephen Tumin
# Data 1233 written to file
# Processing Kenny Everett
# Data 1234 written to file
# Processing Raymond Seitz
# Data 1235 written to file
# Processing Lesley Garrett
# Data 1236 written to file
# Processing Virginia Bottomley MP
# Data 1237 written to file
# Processing Lord Palumbo
# Data 1238 written to file
# Processing Paul Merton
# Data 1239 written to file
# Processing Isabel Allende
# Data 1240 written to file
# Processing Nicholas Hytner
# Data 1241 written to file
# Processing Peter Mayle
# Data 1242 written to file
# Processing Leon Brittan
# Data 1243 written to file
# Processing Joan Baez
# Data 1244 written to file
# Processing Betty Boothroyd MP
# Data 1245 written to file
# Processing Frank Bruno
# Data 1246 written to file
# Processing Kaye Webb
# Data 1247 written to file
# Processing Lord Weinstock
# Data 1248 written to file
# Processing Eva Burrows
# Data 1249 written to file
# Processing John Cole
# Data 1250 written to file
# Processing John Boorman
# Data 1251 written to file
# Processing Baroness Blackstone
# Data 1252 written to file
# Processing Anton Edelmann
# Data 1253 written to file
# Processing Lord Oaksey
# Data 1254 written to file
# Processing Richard Gregory
# Data 1255 written to file
# Processing David Croft
# Data 1256 written to file
# Processing Ken Livingstone MP
# Data 1257 written to file
# Processing Elijah Moshinsky
# Data 1258 written to file
# Processing Robin Butler
# Data 1259 written to file
# Processing Anthony Storr
# Data 1260 written to file
# Processing Evelyn Glennie
# Data 1261 written to file
# Processing Dervla Murphy
# Data 1262 written to file
# Processing Barbara Mills QC
# Data 1263 written to file
# Processing Elizabeth Jennings
# Data 1264 written to file
# Processing Stephen Hawking
# Data 1265 written to file
# Processing Paul Smith
# Data 1266 written to file
# Processing Ghillean Prance
# Data 1267 written to file
# Processing Carmen Callil
# Data 1268 written to file
# Processing Lord Tebbit
# Data 1269 written to file
# Processing John Eliot Gardiner
# Data 1270 written to file
# Processing Christabel Bielenberg
# Data 1271 written to file
# Processing General H Norman Schwarzkopf
# Data 1272 written to file
# Processing Gavin Laird
# Data 1273 written to file
# Processing Julie Andrews
# Data 1274 written to file
# Processing Lord Sainsbury
# Data 1275 written to file
# Processing Juliet Stevenson
# Data 1276 written to file
# Processing Chad Varah
# Data 1277 written to file
# Processing Raymond Blanc
# Data 1278 written to file
# Processing Penelope Leach
# Data 1279 written to file
# Processing Bob Geldof
# Data 1280 written to file
# Processing David Mellor MP
# Data 1281 written to file
# Processing Peregrine Worsthorne
# Data 1282 written to file
# Processing Mohamed Amin
# Data 1283 written to file
# Processing Clare Short MP
# Data 1284 written to file
# Processing Vivienne Westwood
# Data 1285 written to file
# Processing Terry Waite
# Data 1286 written to file
# Processing Robert Lindsay
# Data 1287 written to file
# Processing Duncan Goodhew
# Data 1288 written to file
# Processing Prunella Scales
# Data 1289 written to file
# Processing Lord Chief Justice Taylor
# Data 1290 written to file
# Processing Michael Grade
# Data 1291 written to file
# Processing Will Carling
# Data 1292 written to file
# Processing Henrietta
# Data 1293 written to file
# Processing Anthony Rolfe Johnson
# Data 1294 written to file
# Processing Ernst Gombrich
# Data 1295 written to file
# Processing Lady Soames
# Data 1296 written to file
# Processing Isaiah Berlin
# Data 1297 written to file
# Processing Jocelyn Stevens
# Data 1298 written to file
# Processing Steve Jones
# Data 1299 written to file
# Processing Elvis Costello
# Data 1300 written to file
# Processing Roger Bannister
# Data 1301 written to file
# Processing Robbie Coltrane
# Data 1302 written to file
# Processing J G Ballard
# Data 1303 written to file
# Processing John Major
# Data 1304 written to file
# Processing The  Story
# Data 1305 written to file
# Processing Reverend David Jenkins
# Data 1306 written to file
# Processing Steven Berkoff
# Data 1307 written to file
# Processing Gorden Kaye
# Data 1308 written to file
# Processing Sue Townsend
# Data 1309 written to file
# Processing Fred Dibnah
# Data 1310 written to file
# Processing Dilys Powell
# Data 1311 written to file
# Processing James Lovelock
# Data 1312 written to file
# Processing Lord Delfont
# Data 1313 written to file
# Processing E P Thompson
# Data 1314 written to file
# Processing Alan Alda
# Data 1315 written to file
# Processing Elizabeth Esteve Coll
# Data 1316 written to file
# Processing John Schlesinger
# Data 1317 written to file
# Processing Imran Khan
# Data 1318 written to file
# Processing David Bailey
# Data 1319 written to file
# Processing Klaus Tennstedt
# Data 1320 written to file
# Processing John Banham
# Data 1321 written to file
# Processing Bernice Rubens
# Data 1322 written to file
# Processing Maxwell Hutchinson
# Data 1323 written to file
# Processing Alan Bleasdale
# Data 1324 written to file
# Processing Lord Shawcross
# Data 1325 written to file
# Processing Ron Todd
# Data 1326 written to file
# Processing John Hegarty
# Data 1327 written to file
# Processing A S Byatt
# Data 1328 written to file
# Processing Derek Walcott
# Data 1329 written to file
# Processing Marco Pierre White
# Data 1330 written to file
# Processing John Smith
# Data 1331 written to file
# Processing John Simpson
# Data 1332 written to file
# Processing Cecil Lewis
# Data 1333 written to file
# Processing Dame Shirley Porter
# Data 1334 written to file
# Processing Jonathan Sacks
# Data 1335 written to file
# Processing Lord King
# Data 1336 written to file
# Processing Naomi Mitchison
# Data 1337 written to file
# Processing Marti Caine
# Data 1338 written to file
# Processing Trevor Holdsworth
# Data 1339 written to file
# Processing Jeffrey Bernard
# Data 1340 written to file
# Processing Denis Forman
# Data 1341 written to file
# Processing Ronald Eyre
# Data 1342 written to file
# Processing Dame Ninette De Valois
# Data 1343 written to file
# Processing Paddy Ashdown MP
# Data 1344 written to file
# Processing Ralf Dahrendorf
# Data 1345 written to file
# Processing Brian Eno
# Data 1346 written to file
# Processing Fred Zinnemann
# Data 1347 written to file
# Processing Adelaide Hall
# Data 1348 written to file
# Processing Lord Goodman
# Data 1349 written to file
# Processing Keith Floyd
# Data 1350 written to file
# Processing Brian Keenan
# Data 1351 written to file
# Processing Eduardo Paolozzi
# Data 1352 written to file
# Processing Baroness Trumpington
# Data 1353 written to file
# Processing Elisabeth Welch
# Data 1354 written to file
# Processing Barbara Castle
# Data 1355 written to file
# Processing Lord Annan
# Data 1356 written to file
# Processing Nicholas Snowman
# Data 1357 written to file
# Processing Ernie Wise
# Data 1358 written to file
# Processing Clive Jenkins
# Data 1359 written to file
# Processing John Thaw
# Data 1360 written to file
# Processing Gary Lineker
# Data 1361 written to file
# Processing Barbara Windsor
# Data 1362 written to file
# Processing Ruth Westheimer
# Data 1363 written to file
# Processing Lord Charteris
# Data 1364 written to file
# Processing Robin Knox Johnston
# Data 1365 written to file
# Processing Jean Rook
# Data 1366 written to file
# Processing Peter Jonas
# Data 1367 written to file
# Processing Kaffe Fassett
# Data 1368 written to file
# Processing George Carman QC
# Data 1369 written to file
# Processing Harold Fielding
# Data 1370 written to file
# Processing Maeve Binchy
# Data 1371 written to file
# Processing Ken Dodd
# Data 1372 written to file
# Processing David Blunkett MP
# Data 1373 written to file
# Processing Jonathan Pryce
# Data 1374 written to file
# Processing Molly Keane
# Data 1375 written to file
# Processing Prue Leith
# Data 1376 written to file
# Processing June Whitfield
# Data 1377 written to file
# Processing Mary Wesley
# Data 1378 written to file
# Processing Crispin Tickell
# Data 1379 written to file
# Processing John Biffen MP
# Data 1380 written to file
# Processing Richard Rogers
# Data 1381 written to file
# Processing George Porter
# Data 1382 written to file
# Processing Ian Trethowan
# Data 1383 written to file
# Processing John Sessions
# Data 1384 written to file
# Processing John Pilger
# Data 1385 written to file
# Processing Michael Tilson Thomas
# Data 1386 written to file
# Processing Sarah Miles
# Data 1387 written to file
# Processing Lord Weidenfeld
# Data 1388 written to file
# Processing Robin Day
# Data 1389 written to file
# Processing John Peel
# Data 1390 written to file
# Processing Dennis Skinner
# Data 1391 written to file
# Processing Dirk Bogarde
# Data 1392 written to file
# Processing HRH The Duchess of Kent
# Data 1393 written to file
# Processing Pauline Collins
# Data 1394 written to file
# Processing Rt. Hon. Nigel Lawson
# Data 1395 written to file
# Processing Lady Mosley
# Data 1396 written to file
# Processing Seamus Heaney
# Data 1397 written to file
# Processing Michael Codron
# Data 1398 written to file
# Processing Ian Botham
# Data 1399 written to file
# Processing Colin Thubron
# Data 1400 written to file
# Processing Alan Plater
# Data 1401 written to file
# Processing Jack Lemmon
# Data 1402 written to file
# Processing Lucinda Lambton
# Data 1403 written to file
# Processing John Ogdon
# Data 1404 written to file
# Processing Penelope Lively
# Data 1405 written to file
# Processing Eric Clapton
# Data 1406 written to file
# Processing Dame Vera Lynn
# Data 1407 written to file
# Processing Thomas Armstrong
# Data 1408 written to file
# Processing Ned Sherrin
# Data 1409 written to file
# Processing Mark McCormack
# Data 1410 written to file
# Processing Joan Collins
# Data 1411 written to file
# Processing Maria Aitken
# Data 1412 written to file
# Processing Jonathon Porritt
# Data 1413 written to file
# Processing Richard Branson
# Data 1414 written to file
# Processing Nicholas Henderson
# Data 1415 written to file
# Processing Katharine Hamnett
# Data 1416 written to file
# Processing Thora Hird
# Data 1417 written to file
# Processing Lenny Henry
# Data 1418 written to file
# Processing Lady Redgrave
# Data 1419 written to file
# Processing Miriam Rothschild
# Data 1420 written to file
# Processing Lord Roy Jenkins
# Data 1421 written to file
# Processing Leslie Grantham
# Data 1422 written to file
# Processing Stephen Spender
# Data 1423 written to file
# Processing Gerald Scarfe
# Data 1424 written to file
# Processing Dame Josephine Barnes
# Data 1425 written to file
# Processing David Hare
# Data 1426 written to file
# Processing Enoch Powell
# Data 1427 written to file
# Processing Jeffrey Tate
# Data 1428 written to file
# Processing Rocco Forte
# Data 1429 written to file
# Processing Joan Armatrading
# Data 1430 written to file
# Processing Boy George
# Data 1431 written to file
# Processing Tony Benn
# Data 1432 written to file
# Processing Twiggy
# Data 1433 written to file
# Processing Most Rev Robert Runcie
# Data 1434 written to file
# Processing Edward Heath
# Data 1435 written to file
# Processing Charles Dance
# Data 1436 written to file
# Processing Lady Warnock
# Data 1437 written to file
# Processing Stephen Fry
# Data 1438 written to file
# Processing Bob Champion
# Data 1439 written to file
# Processing Bob Hoskins
# Data 1440 written to file
# Processing Claus Moser
# Data 1441 written to file
# Processing Germaine Greer
# Data 1442 written to file
# Processing Rt. Hon. Michael Foot
# Data 1443 written to file
# Processing Cilla Black
# Data 1444 written to file
# Processing Terry Wogan
# Data 1445 written to file
# Processing Athene Seyler
# Data 1446 written to file
# Processing Bishop Trevor Huddleston
# Data 1447 written to file
# Processing Salman Rushdie
# Data 1448 written to file
# Processing Peter Donohoe
# Data 1449 written to file
# Processing Alfred Wainwright
# Data 1450 written to file
# Processing Anita Dobson
# Data 1451 written to file
# Processing Lord Dacre of Glanton Hugh Trevor Roper
# Data 1452 written to file
# Processing Patricia Neal
# Data 1453 written to file
# Processing Reverend Ian Paisley
# Data 1454 written to file
# Processing Joan Turner
# Data 1455 written to file
# Processing Lord Armstrong
# Data 1456 written to file
# Processing Dame Edna Everage
# Data 1457 written to file
# Processing David Essex
# Data 1458 written to file
# Processing David Owen
# Data 1459 written to file
# Processing Jeremy Isaacs
# Data 1460 written to file
# Processing Gwen Ffrangcon Davies
# Data 1461 written to file
# Processing Rt. Hon. Douglas Hurd
# Data 1462 written to file
# Processing Anton Mosimann
# Data 1463 written to file
# Processing Rabbi Lionel Blue
# Data 1464 written to file
# Processing Anita Roddick
# Data 1465 written to file
# Processing Rowan Atkinson
# Data 1466 written to file
# Processing Peggy Makins
# Data 1467 written to file
# Processing Neil Kinnock
# Data 1468 written to file
# Processing Michael Gambon
# Data 1469 written to file
# Processing Mary Archer
# Data 1470 written to file
# Processing Arthur Scargill
# Data 1471 written to file
# Processing Jane Asher
# Data 1472 written to file
# Processing Quintin Hogg
# Data 1473 written to file
# Processing Brendan Foster
# Data 1474 written to file
# Processing James Burke
# Data 1475 written to file
# Processing Stephanie Beacham
# Data 1476 written to file
# Processing Dennis Potter
# Data 1477 written to file
# Processing William Davis
# Data 1478 written to file
# Processing Margaret Kelly   Miss Bluebell
# Data 1479 written to file
# Processing Lord Donoughue
# Data 1480 written to file
# Processing Gemma Craven
# Data 1481 written to file
# Processing Rt. Hon. Michael Heseltine
# Data 1482 written to file
# Processing Adele Leigh
# Data 1483 written to file
# Processing Lew Grade
# Data 1484 written to file
# Processing Antony Sher
# Data 1485 written to file
# Processing Vernon Scannell
# Data 1486 written to file
# Processing In memory of comedian and writer Barry Cryer
# Data 1487 written to file
# Processing Robert Carrier
# Data 1488 written to file
# Processing Sue Lawley
# Data 1489 written to file
# Processing Bamber Gascoigne
# Data 1490 written to file
# Processing Bernard Levin
# Data 1491 written to file
# Processing James Callaghan
# Data 1492 written to file
# Processing Lord Killanin
# Data 1493 written to file
# Processing Lulu
# Data 1494 written to file
# Processing Jacques Loussier
# Data 1495 written to file
# Processing Peter West
# Data 1496 written to file
# Processing Joanna Lumley
# Data 1497 written to file
# Processing Kitty Godfree
# Data 1498 written to file
# Processing Lord Montagu
# Data 1499 written to file
# Processing Edna O'Brien
# Data 1500 written to file
# Processing Susan George
# Data 1501 written to file
# Processing Frances Edmonds
# Data 1502 written to file
# Processing Maya Angelou
# Data 1503 written to file
# Processing Kenneth Williams
# Data 1504 written to file
# Processing Lucinda Green
# Data 1505 written to file
# Processing Elaine Paige
# Data 1506 written to file
# Processing Robert Maxwell
# Data 1507 written to file
# Processing Terence Stamp
# Data 1508 written to file
# Processing Frank Bough
# Data 1509 written to file
# Processing Michael Bogdanov
# Data 1510 written to file
# Processing Julian Critchley
# Data 1511 written to file
# Processing Anthony Andrews
# Data 1512 written to file
# Processing Peter Alliss
# Data 1513 written to file
# Processing David Penhaligon
# Data 1514 written to file
# Processing Dora Bryan
# Data 1515 written to file
# Processing Johnny Mathis
# Data 1516 written to file
# Processing Nicholas Goodison
# Data 1517 written to file
# Processing Ken Russell
# Data 1518 written to file
# Processing Michael Hordern
# Data 1519 written to file
# Processing Victoria Wood
# Data 1520 written to file
# Processing Peter Fluck & Roger Law
# Data 1521 written to file
# Processing Baroness Sue Ryder of Warsaw
# Data 1522 written to file
# Processing Jeremy Lloyd
# Data 1523 written to file
# Processing James Prior
# Data 1524 written to file
# Processing Tony Bennett
# Data 1525 written to file
# Processing Benny Green
# Data 1526 written to file
# Processing Jackie Collins
# Data 1527 written to file
# Processing Nigel Hawthorne
# Data 1528 written to file
# Processing John Ridgway
# Data 1529 written to file
# Processing Hal Prince
# Data 1530 written to file
# Processing Kingsley Amis
# Data 1531 written to file
# Processing Jeremy Irons
# Data 1532 written to file
# Processing Albert & Michel Roux
# Data 1533 written to file
# Processing Phil Edmonds
# Data 1534 written to file
# Processing Fred Hoyle
# Data 1535 written to file
# Processing Ian MacGregor
# Data 1536 written to file
# Processing Richard Condon
# Data 1537 written to file
# Processing Suzi Quatro
# Data 1538 written to file
# Processing James Herbert
# Data 1539 written to file
# Processing Andrew Davis
# Data 1540 written to file
# Processing Auberon Waugh
# Data 1541 written to file
# Processing Stan Barstow
# Data 1542 written to file
# Processing Jane Lapotaire
# Data 1543 written to file
# Processing Virginia Holgate
# Data 1544 written to file
# Processing Norman Lewis
# Data 1545 written to file
# Processing Roger Vadim
# Data 1546 written to file
# Processing Geoffrey Howe
# Data 1547 written to file
# Processing David Wilson
# Data 1548 written to file
# Processing Brian Redhead
# Data 1549 written to file
# Processing Anne Sophie Mutter
# Data 1550 written to file
# Processing Jackie Stewart
# Data 1551 written to file
# Processing Max Hastings
# Data 1552 written to file
# Processing Ismail Merchant
# Data 1553 written to file
# Processing Elton John
# Data 1554 written to file
# Processing Bobby Robson
# Data 1555 written to file
# Processing Arthur Hailey
# Data 1556 written to file
# Processing Jane Glover
# Data 1557 written to file
# Processing Shirley Williams
# Data 1558 written to file
# Processing Ron Pickering
# Data 1559 written to file
# Processing Beryl Bainbridge
# Data 1560 written to file
# Processing John Dankworth
# Data 1561 written to file
# Processing Selina Scott
# Data 1562 written to file
# Processing Ben Kingsley
# Data 1563 written to file
# Processing Bruce Oldfield
# Data 1564 written to file
# Processing Dennis Taylor
# Data 1565 written to file
# Processing Roy Hattersley
# Data 1566 written to file
# Processing Maureen Lipman
# Data 1567 written to file
# Processing Nigel Kennedy
# Data 1568 written to file
# Processing Alan Parker
# Data 1569 written to file
# Processing Sheila Steafel
# Data 1570 written to file
# Processing David Steel MP
# Data 1571 written to file
# Processing Barbara Taylor Bradford
# Data 1572 written to file
# Processing Robert Burchfield
# Data 1573 written to file
# Processing Joseph Allen
# Data 1574 written to file
# Processing Doris Stokes
# Data 1575 written to file
# Processing Jimmy Savile
# Data 1576 written to file
# Processing Richard Eyre
# Data 1577 written to file
# Processing Gordon Beningfield
# Data 1578 written to file
# Processing Alison Lurie
# Data 1579 written to file
# Processing Jorge Bolet
# Data 1580 written to file
# Processing Anthony Hopkins
# Data 1581 written to file
# Processing Michael Elkins
# Data 1582 written to file
# Processing Elly Ameling
# Data 1583 written to file
# Processing Julie Walters
# Data 1584 written to file
# Processing Madhur Jaffrey
# Data 1585 written to file
# Processing John Harvey Jones
# Data 1586 written to file
# Processing Tom Stoppard
# Data 1587 written to file
# Processing Michael Tippett
# Data 1588 written to file
# Processing Ray Cooney
# Data 1589 written to file
# Processing John Burgh
# Data 1590 written to file
# Processing Miklos Rozsa
# Data 1591 written to file
# Processing Robin Hanbury Tenison
# Data 1592 written to file
# Processing David Puttnam
# Data 1593 written to file
# Processing Vernon Handley
# Data 1594 written to file
# Processing Tom Sharpe
# Data 1595 written to file
# Processing David Rendall
# Data 1596 written to file
# Processing Jonathan Lynn
# Data 1597 written to file
# Processing Michael Ffolkes
# Data 1598 written to file
# Processing John Surman
# Data 1599 written to file
# Processing John Hurt
# Data 1600 written to file
# Processing Alfred Eisenstadt
# Data 1601 written to file
# Processing Gerry Cottle
# Data 1602 written to file
# Processing Catherine Cookson
# Data 1603 written to file
# Processing George Abbott
# Data 1604 written to file
# Processing Ved Mehta
# Data 1605 written to file
# Processing Willie Rushton
# Data 1606 written to file
# Processing Ron Goodwin
# Data 1607 written to file
# Processing Gayatri Devi
# Data 1608 written to file
# Processing Alfred Ayer
# Data 1609 written to file
# Processing Natalia Makarova
# Data 1610 written to file
# Processing Vlado Perlemuter
# Data 1611 written to file
# Processing Lord Rothschild
# Data 1612 written to file
# Processing Zubin Mehta
# Data 1613 written to file
# Processing Hugh Johnson
# Data 1614 written to file
# Processing Rosalind Plowright
# Data 1615 written to file
# Processing Leo McKern
# Data 1616 written to file
# Processing David Lodge
# Data 1617 written to file
# Processing Lucy Irvine
# Data 1618 written to file
# Processing Christopher Reeve
# Data 1619 written to file
# Processing Paul Tortelier
# Data 1620 written to file
# Processing 'Honest' Ed Mirvish
# Data 1621 written to file
# Processing Michael Quinn
# Data 1622 written to file
# Processing Don McCullin
# Data 1623 written to file
# Processing Gerald Priestland
# Data 1624 written to file
# Processing Michael York
# Data 1625 written to file
# Processing Woody Herman
# Data 1626 written to file
# Processing Lord Elwyn Jones
# Data 1627 written to file
# Processing Stubby Kaye
# Data 1628 written to file
# Processing HRH Princess Michael of Kent
# Data 1629 written to file
# Processing Quentin Crewe
# Data 1630 written to file
# Processing David Gower
# Data 1631 written to file
# Processing Bertice Reading
# Data 1632 written to file
# Processing M M Kaye
# Data 1633 written to file
# Processing James Stewart
# Data 1634 written to file
# Processing John Piper
# Data 1635 written to file
# Processing Marvin Hamlisch
# Data 1636 written to file
# Processing Thomas Keneally
# Data 1637 written to file
# Processing Hugh Greene
# Data 1638 written to file
# Processing Peter Hall
# Data 1639 written to file
# Processing Shirley MacLaine
# Data 1640 written to file
# Processing Ranulph Fiennes
# Data 1641 written to file
# Processing Linda Esther Gray
# Data 1642 written to file
# Processing Topol
# Data 1643 written to file
# Processing Mollie Harris
# Data 1644 written to file
# Processing Rosemary Sutcliff
# Data 1645 written to file
# Processing Ian Richardson
# Data 1646 written to file
# Processing Lionel Hampton
# Data 1647 written to file
# Processing Charlotte Lamb
# Data 1648 written to file
# Processing Paul Jones
# Data 1649 written to file
# Processing Cindy Buxton & Annie Price
# Data 1650 written to file
# Processing Malcolm Bradbury
# Data 1651 written to file
# Processing Peter Bull
# Data 1652 written to file
# Processing Frederick Gibberd
# Data 1653 written to file
# Processing Keith Waterhouse
# Data 1654 written to file
# Processing John Gunter
# Data 1655 written to file
# Processing John Pritchard
# Data 1656 written to file
# Processing Julian Bream
# Data 1657 written to file
# Processing Terry Jones
# Data 1658 written to file
# Processing Peter Maxwell Davies
# Data 1659 written to file
# Processing Fleur Cowles
# Data 1660 written to file
# Processing Peter Pears
# Data 1661 written to file
# Processing Raymond Briggs
# Data 1662 written to file
# Processing Sinead Cusack
# Data 1663 written to file
# Processing Terry Wogan
# Data 1664 written to file
# Processing Alan King Hamilton
# Data 1665 written to file
# Processing Arthur English
# Data 1666 written to file
# Processing A N Wilson
# Data 1667 written to file
# Processing Max Boyce
# Data 1668 written to file
# Processing Geoffrey Moorhouse
# Data 1669 written to file
# Processing Ruggiero Ricci
# Data 1670 written to file
# Processing James Fox
# Data 1671 written to file
# Processing Jan Morris
# Data 1672 written to file
# Processing Michael Wood
# Data 1673 written to file
# Processing Douglas Reeman
# Data 1674 written to file
# Processing Kenneth Macmillan
# Data 1675 written to file
# Processing Tom Keating
# Data 1676 written to file
# Processing James Ivory
# Data 1677 written to file
# Processing Zandra Rhodes
# Data 1678 written to file
# Processing Beryl Reid
# Data 1679 written to file
# Processing Tim Severin
# Data 1680 written to file
# Processing Gwyneth Jones
# Data 1681 written to file
# Processing Baroness Maria Von Trapp
# Data 1682 written to file
# Processing Steve Davis
# Data 1683 written to file
# Processing Rachel Billington
# Data 1684 written to file
# Processing Mary Ellis
# Data 1685 written to file
# Processing Gyorgy Ligeti
# Data 1686 written to file
# Processing Alan Price
# Data 1687 written to file
# Processing Helen Mirren
# Data 1688 written to file
# Processing P D James
# Data 1689 written to file
# Processing Rosamond Lehmann
# Data 1690 written to file
# Processing Thomas Allen
# Data 1691 written to file
# Processing George Thomas
# Data 1692 written to file
# Processing Mike Harding
# Data 1693 written to file
# Processing Geoffrey Grigson
# Data 1694 written to file
# Processing N.Busch
# Data 1695 written to file
# Processing David Lloyd Jones
# Data 1696 written to file
# Processing Wilbur Smith
# Data 1697 written to file
# Processing Carlo Curley
# Data 1698 written to file
# Processing James Loughran
# Data 1699 written to file
# Processing Claire Bloom
# Data 1700 written to file
# Processing Duke & Duchess of Devonshire
# Data 1701 written to file
# Processing Carl Davis
# Data 1702 written to file
# Processing Donald Sinden
# Data 1703 written to file
# Processing Dame Janet Baker
# Data 1704 written to file
# Processing George Martin
# Data 1705 written to file
# Processing Lyall Watson
# Data 1706 written to file
# Processing Pamela Stephenson
# Data 1707 written to file
# Processing Captain Jacques Cousteau
# Data 1708 written to file
# Processing John Mortimer QC
# Data 1709 written to file
# Processing Joss Ackland
# Data 1710 written to file
# Processing Eric Newby
# Data 1711 written to file
# Processing Anton Dolin
# Data 1712 written to file
# Processing Delia Smith
# Data 1713 written to file
# Processing Desmond Hawkins
# Data 1714 written to file
# Processing Marti Webb
# Data 1715 written to file
# Processing Julian Symons
# Data 1716 written to file
# Processing Lucia Popp
# Data 1717 written to file
# Processing Jenny Agutter
# Data 1718 written to file
# Processing Dorothy Dunnett
# Data 1719 written to file
# Processing Brian Aldiss
# Data 1720 written to file
# Processing Julia McKenzie
# Data 1721 written to file
# Processing Richard Armstrong
# Data 1722 written to file
# Processing William Walton
# Data 1723 written to file
# Processing Lord Bernard Miles
# Data 1724 written to file
# Processing George Chisholm
# Data 1725 written to file
# Processing Dame Eva Turner
# Data 1726 written to file
# Processing John Osborne
# Data 1727 written to file
# Processing Petula Clark
# Data 1728 written to file
# Processing Christopher Leaver
# Data 1729 written to file
# Processing J K Galbraith
# Data 1730 written to file
# Processing Paul McCartney
# Data 1731 written to file
# Processing Frankie Howerd
# Data 1732 written to file
# Processing Angela Rippon
# Data 1733 written to file
# Processing Martin Gilbert
# Data 1734 written to file
# Processing Trevor Brooking
# Data 1735 written to file
# Processing Earl of Harewood
# Data 1736 written to file
# Processing Helene Hanff
# Data 1737 written to file
# Processing Jack Higgins
# Data 1738 written to file
# Processing Alan Howard
# Data 1739 written to file
# Processing Douglas Bader
# Data 1740 written to file
# Processing Diana Dors
# Data 1741 written to file
# Processing James Clavell
# Data 1742 written to file
# Processing Glyn Daniel
# Data 1743 written to file
# Processing Patrick Lichfield
# Data 1744 written to file
# Processing Joseph Cotten
# Data 1745 written to file
# Processing Elspeth Huxley
# Data 1746 written to file
# Processing Montserrat Caballe
# Data 1747 written to file
# Processing Beaux Arts Trio
# Data 1748 written to file
# Processing James Mason
# Data 1749 written to file
# Processing Malcolm Muggeridge
# Data 1750 written to file
# Processing Jessye Norman
# Data 1751 written to file
# Processing Alan Jones
# Data 1752 written to file
# Processing Frank Oz
# Data 1753 written to file
# Processing Paul Eddington
# Data 1754 written to file
# Processing Sebastian Coe
# Data 1755 written to file
# Processing Terry Hands
# Data 1756 written to file
# Processing Julian Lloyd Webber
# Data 1757 written to file
# Processing Roger Moore
# Data 1758 written to file
# Processing Carl Sagan
# Data 1759 written to file
# Processing Gillian Lynne
# Data 1760 written to file
# Processing Gloria Swanson
# Data 1761 written to file
# Processing Morris West
# Data 1762 written to file
# Processing Giuseppe Di Stefano
# Data 1763 written to file
# Processing Richard Leakey
# Data 1764 written to file
# Processing William Whitelaw
# Data 1765 written to file
# Processing Eric Shilling
# Data 1766 written to file
# Processing Edmund Rubbra
# Data 1767 written to file
# Processing John Gielgud
# Data 1768 written to file
# Processing Buddy Rich
# Data 1769 written to file
# Processing Frederick Ashton
# Data 1770 written to file
# Processing Stewart Granger
# Data 1771 written to file
# Processing Princess Grace of Monaco
# Data 1772 written to file
# Processing Fitzroy MacLean
# Data 1773 written to file
# Processing Gary Glitter
# Data 1774 written to file
# Processing Patricia Ruanne
# Data 1775 written to file
# Processing Russell Harty
# Data 1776 written to file
# Processing Peter Nichols
# Data 1777 written to file
# Processing Daniel Massey
# Data 1778 written to file
# Processing Carla Lane
# Data 1779 written to file
# Processing Frederic Raphael
# Data 1780 written to file
# Processing David Broome
# Data 1781 written to file
# Processing Mary O'Hara
# Data 1782 written to file
# Processing Jeffrey Archer
# Data 1783 written to file
# Processing Joan Plowright
# Data 1784 written to file
# Processing HRH Princess Margaret
# Data 1785 written to file
# Processing John Fowles
# Data 1786 written to file
# Processing Robin Cousins
# Data 1787 written to file
# Processing Placido Domingo
# Data 1788 written to file
# Processing Arthur Askey
# Data 1789 written to file
# Processing Neville Marriner
# Data 1790 written to file
# Processing Jose Carreras
# ...
# Data 3049 written to file
# Processing John Watt
# Data 3050 written to file
# Processing Malcolm Muggeridge
# Data 3051 written to file
# Processing Dennis Noble
# Data 3052 written to file
# Processing Donald Campbell
# Data 3053 written to file
# Processing Isobel Barnett
# Data 3054 written to file
# Processing Anthony Steel
# Data 3055 written to file
# Processing Peter Katin
# Data 3056 written to file
# Processing Ada Cherry Kearton
# Data 3057 written to file
# Processing Kenneth Tynan
# Data 3058 written to file
# Processing Turner Layton
# Data 3059 written to file
# Processing Valentine Britten
# Data 3060 written to file
# Processing Harry Secombe
# Data 3061 written to file
# Processing Humphrey Lyttelton
# Data 3062 written to file
# Processing Bernard Newman
# Data 3063 written to file
# Processing Dennis Price
# Data 3064 written to file
# Processing Dennis Brain
# Data 3065 written to file
# Processing Peter Ustinov
# Data 3066 written to file
# Processing Shirley Abicair
# Data 3067 written to file
# Processing Tex Ritter
# Data 3068 written to file
# Processing Dame Eva Turner
# Data 3069 written to file
# Processing Jim Laker
# Data 3070 written to file
# Processing Leslie Caron
# Data 3071 written to file
# Processing Eric Maschwitz
# Data 3072 written to file
# Processing Eartha Kitt
# Data 3073 written to file
# Processing Ted Heath
# Data 3074 written to file
# Processing Stirling Moss
# Data 3075 written to file
# Processing Robert Atkins
# Data 3076 written to file
# Processing David Hughes
# Data 3077 written to file
# Processing Dora Labbette
# Data 3078 written to file
# Processing Len Harvey
# Data 3079 written to file
# Processing Athene Seyler
# Data 3080 written to file
# Processing John Neville
# Data 3081 written to file
# Processing Marie Burke
# Data 3082 written to file
# Processing Stan Kenton
# Data 3083 written to file
# Processing Bebe Daniels
# Data 3084 written to file
# Processing Cyril Smith
# Data 3085 written to file
# Processing Vanessa Lee
# Data 3086 written to file
# Processing Donald Sinden
# Data 3087 written to file
# Processing Nancy Spain
# Data 3088 written to file
# Processing Kenneth More
# Data 3089 written to file
# Processing Robert Fabian
# Data 3090 written to file
# Processing Terry Thomas
# Data 3091 written to file
# Processing David Nixon
# Data 3092 written to file
# Processing Dora Bryan
# Data 3093 written to file
# Processing Sam Costa
# Data 3094 written to file
# Processing Laurence Harvey
# Data 3095 written to file
# Processing Anton Dolin
# Data 3096 written to file
# Processing Bob Monkhouse and Denis Goodwin
# Data 3097 written to file
# Processing Bernard Braden
# Data 3098 written to file
# Processing Jack Train
# Data 3099 written to file
# Processing Beverley Nichols
# Data 3100 written to file
# Processing Vic Oliver
# Data 3101 written to file
# Processing Valentine Dyall
# Data 3102 written to file
# Processing Frances Day
# Data 3103 written to file
# Processing Sidonie Goossens
# Data 3104 written to file
# Processing James Robertson Justice
# Data 3105 written to file
# Processing Max Bygraves
# Data 3106 written to file
# Processing John Gregson
# Data 3107 written to file
# Processing Leslie Welch
# Data 3108 written to file
# Processing Philip Harben
# Data 3109 written to file
# Processing Eileen Joyce
# Data 3110 written to file
# Processing Herbert Wilcox
# Data 3111 written to file
# Processing R C Sherriff
# Data 3112 written to file
# Processing Claire Bloom
# Data 3113 written to file
# Processing Michael Ayrton
# Data 3114 written to file
# Processing Isobel Baillie
# Data 3115 written to file
# Processing Edward Allcard
# Data 3116 written to file
# Processing Ursula Jeans
# Data 3117 written to file
# Processing Lionel Gamlin
# Data 3118 written to file
# Processing Yehudi Menuhin
# Data 3119 written to file
# Processing Michael Redgrave
# Data 3120 written to file
# Processing Nicholas Monsarrat
# Data 3121 written to file
# Processing Tony Mottram
# Data 3122 written to file
# Processing Emlyn Williams
# Data 3123 written to file
# Processing Barbara Kelly
# Data 3124 written to file
# Processing Tommy Farr
# Data 3125 written to file
# Processing Anthony Asquith
# Data 3126 written to file
# Processing Malcolm Sargent
# Data 3127 written to file
# Processing Arthur Askey
# Data 3128 written to file
# Processing Tod Slaughter
# Data 3129 written to file
# Processing Alan P Herbert
# Data 3130 written to file
# Processing Pat Kirkwood
# Data 3131 written to file
# Processing Pat Smythe
# Data 3132 written to file
# Processing Chris Chataway
# Data 3133 written to file
# Processing Osbert Lancaster
# Data 3134 written to file
# Processing Robert Harris
# Data 3135 written to file
# Processing Eric Ambler
# Data 3136 written to file
# Processing Harriet Cohen
# Data 3137 written to file
# Processing Cedric Hardwicke
# Data 3138 written to file
# Processing Dorothy Tutin
# Data 3139 written to file
# Processing Bobby Howes
# Data 3140 written to file
# Processing Dorothy Ward
# Data 3141 written to file
# Processing Margaret Leighton
# Data 3142 written to file
# Processing Fred Hoyle
# Data 3143 written to file
# Processing Reginald Dixon
# Data 3144 written to file
# Processing Captain M E B Banks RM
# Data 3145 written to file
# Processing Celia Johnson
# Data 3146 written to file
# Processing Robert Henriques
# Data 3147 written to file
# Processing Evelyn Laye
# Data 3148 written to file
# Processing Nigel Balchin
# Data 3149 written to file
# Processing Valerie Hobson
# Data 3150 written to file
# Processing T E B Clarke
# Data 3151 written to file
# Processing John Betjeman
# Data 3152 written to file
# Processing Jessie Matthews
# Data 3153 written to file
# Processing Vivian De Gurr St George
# Data 3154 written to file
# Processing Mary Ellis
# Data 3155 written to file
# Processing Bernard Miles
# Data 3156 written to file
# Processing Jack Warner
# Data 3157 written to file
# Processing Peggy Cummins
# Data 3158 written to file
# Processing Hugh Sinclair
# Data 3159 written to file
# Processing Leslie A "Hutch" Hutchinson
# Data 3160 written to file
# Processing Alfredo Campoli
# Data 3161 written to file
# Processing Hugh Williams
# Data 3162 written to file
# Processing Nora Swinburne
# Data 3163 written to file
# Processing Cyril Ritchard
# Data 3164 written to file
# Processing Brian Reece
# Data 3165 written to file
# Processing Cecil Parker
# Data 3166 written to file
# Processing Geraldine McEwan
# Data 3167 written to file
# Processing Lizbeth Webb
# Data 3168 written to file
# Processing Leo Genn
# Data 3169 written to file
# Processing Robert Helpmann
# Data 3170 written to file
# Processing Ralph Richardson
# Data 3171 written to file
# Processing Pamela Kellino
# Data 3172 written to file
# Processing Arthur Wint
# Data 3173 written to file
# Processing Naunton Wayne
# Data 3174 written to file
# Processing Jack Hawkins
# Data 3175 written to file
# Processing John Arlott
# Data 3176 written to file
# Processing Isabel Jeans
# Data 3177 written to file
# Processing Norman Wisdom
# Data 3178 written to file
# Processing Yolande Donlan
# Data 3179 written to file
# Processing Webster Booth
# Data 3180 written to file
# Processing Moira Lister
# Data 3181 written to file
# Processing Max Miller
# Data 3182 written to file
# Processing Pamela Brown
# Data 3183 written to file
# Processing Richard Todd
# Data 3184 written to file
# Processing Sheila Sim
# Data 3185 written to file
# Processing David Tomlinson
# Data 3186 written to file
# Processing Jean Carson
# Data 3187 written to file
# Processing Donald Wolfit
# Data 3188 written to file
# Processing Duncan Carse
# Data 3189 written to file
# Processing Belita
# Data 3190 written to file
# Processing Ralph Lynn
# Data 3191 written to file
# Processing Margaret Rutherford
# Data 3192 written to file
# Processing Wilfred Pickles
# Data 3193 written to file
# Processing Joy Nichols
# Data 3194 written to file
# Processing Bill Greenslade
# Data 3195 written to file
# Processing Gordon Harker
# Data 3196 written to file
# Processing Sonnie Hale
# Data 3197 written to file
# Processing Ada Reeve
# Data 3198 written to file
# Processing Nigel Patrick
# Data 3199 written to file
# Processing Tessie O'Shea
# Data 3200 written to file
# Processing W MacQueen Pope
# Data 3201 written to file
# Processing Florence Desmond
# Data 3202 written to file
# Processing Joy Worth
# Data 3203 written to file
# Processing Binnie Hale
# Data 3204 written to file
# Processing Esmond Knight
# Data 3205 written to file
# Processing Winifred Atwell
# Data 3206 written to file
# Processing Ted Ray
# Data 3207 written to file
# Processing Vivien Leigh
# Data 3208 written to file
# Processing Richard Attenborough
# Data 3209 written to file
# Processing Anne Shelton
# Data 3210 written to file
# Processing Trevor Howard
# Data 3211 written to file
# Processing Michael Denison & Dulcie Gray
# Data 3212 written to file
# Processing Joan Greenwood
# Data 3213 written to file
# Processing Christopher Stone
# Data 3214 written to file
# Processing Dame Gladys Cooper
# Data 3215 written to file
# Processing Henry Hall
# Data 3216 written to file
# Processing Fred Perry
# Data 3217 written to file
# Processing Boyd Neel
# Data 3218 written to file
# Processing Ellaline Terriss
# Data 3219 written to file
# Processing Godfrey Winn
# Data 3220 written to file
# Processing Googie Withers
# Data 3221 written to file
# Processing Gilbert Harding
# Data 3222 written to file
# Processing Dorothy Dickson
# Data 3223 written to file
# Processing Robert Beatty
# Data 3224 written to file
# Processing Fay Compton
# Data 3225 written to file
# Processing Kirsten Flagstad
# Data 3226 written to file
# Processing Richard Murdoch & Kenneth Horne
# Data 3227 written to file
# Processing Delia Murphy
# Data 3228 written to file
# Processing Wynford Vaughan Thomas
# Data 3229 written to file
# Processing Richard Hearne
# Data 3230 written to file
# Processing Anna Neagle
# Data 3231 written to file
# Processing Fred Emney
# Data 3232 written to file
# Processing Hermione Gingold
# Data 3233 written to file
# Processing Roger Livesey
# Data 3234 written to file
# Processing Elisabeth Welch
# Data 3235 written to file
# Processing Compton MacKenzie
# Data 3236 written to file
# Processing Peter Brough & Archie Andrews
# Data 3237 written to file
# Processing Jeanne De Casalis
# Data 3238 written to file
# Processing Spike Hughes
# Data 3239 written to file
# Processing Sybil Thorndike
# Data 3240 written to file
# Processing Carroll Gibbons
# Data 3241 written to file
# Processing Jack Hulbert
# Data 3242 written to file
# Processing Dame Vera Lynn
# Data 3243 written to file
# Processing John Mills
# Data 3244 written to file
# Processing Elisabeth Schumann
# Data 3245 written to file
# Processing Kathleen Harrison
# Data 3246 written to file
# Processing George Formby
# Data 3247 written to file
# Processing Diana Wynyard
# Data 3248 written to file
# Processing Ronald Shiner
# Data 3249 written to file
# Processing Clemence Dane
# Data 3250 written to file
# Processing Gerald Moore
# Data 3251 written to file
# Processing Henry Kendall
# Data 3252 written to file
# Processing Mai Zetterling
# Data 3253 written to file
# Processing George Robey
# Data 3254 written to file
# Processing Sally Ann Howes
# Data 3255 written to file
# Processing Freddie Mills
# Data 3256 written to file
# Processing Anne Crawford
# Data 3257 written to file
# Processing Vivian Ellis
# Data 3258 written to file
# Processing Phyllis Calvert
# Data 3259 written to file
# Processing A E Matthews
# Data 3260 written to file
# Processing Joyce Grenfell
# Data 3261 written to file
# Processing Jimmy Edwards
# Data 3262 written to file
# Processing Jean Kent
# Data 3263 written to file
# Processing Leslie Henson
# Data 3264 written to file
# Processing Cicely Courtneidge
# Data 3265 written to file
# Processing Stanley Holloway
# Data 3266 written to file
# Processing Bill Johnson
# Data 3267 written to file
# Processing Eric Coates
# Data 3268 written to file
# Processing Gracie Fields
# Data 3269 written to file
# Processing Tommy Trinder
# Data 3270 written to file
# Processing Dame Maggie Teyte
# Data 3271 written to file
# Processing Ann Todd
# Data 3272 written to file
# Processing Denis Compton & W J Edrich
# Data 3273 written to file
# Processing Larry Adler
# Data 3274 written to file
# Processing Petula Clark
# Data 3275 written to file
# Processing Margaret Lockwood
# Data 3276 written to file
# Processing Peter Fleming
# Data 3277 written to file
# Processing Muir Mathieson
# Data 3278 written to file
# Processing Anona Winn
# Data 3279 written to file
# Processing Ted Kavanagh
# Data 3280 written to file
# Processing John Clements
# Data 3281 written to file
# Processing Joan Hammond
# Data 3282 written to file
# Processing Peter Ustinov
# Data 3283 written to file
# Processing Kay Hammond
# Data 3284 written to file
# Processing Jack Buchanan
# Data 3285 written to file
# Processing Constance Cummings
# Data 3286 written to file
# Processing Peter Scott
# Data 3287 written to file
# Processing Donald Peers
# Data 3288 written to file
# Processing Yvonne Arnaud
# Data 3289 written to file
# Processing Robertson Hare
# Data 3290 written to file
# Processing Monica Dickens
# Data 3291 written to file
# Processing Eric Portman
# Data 3292 written to file
# Processing Barbara Mullen
# Data 3293 written to file
# Processing Sonia Dresdel
# Data 3294 written to file
# Processing Nova Pilbeam
# Data 3295 written to file
# Processing Richard Goolden
# Data 3296 written to file
# Processing Stewart Granger
# Data 3297 written to file
# Processing Eileen Joyce
# Data 3298 written to file
# Processing Signalman Henry Wheeler
# Data 3299 written to file
# Processing Deborah Kerr
# Data 3300 written to file
# Processing Bobby Howes
# Data 3301 written to file
# Processing Valerie Hobson
# Data 3302 written to file
# Processing Celia Johnson
# Data 3303 written to file
# Processing C E M Joad
# Data 3304 written to file
# Processing Claire Luce
# Data 3305 written to file
# Processing Michael Redgrave
# Data 3306 written to file
# Processing Margaret Hubble
# Data 3307 written to file
# Processing Pat Butler
# Data 3308 written to file
# Processing Alvar Lidell
# Data 3309 written to file
# Processing Roy Williams
# Data 3310 written to file
# Processing Joan Edgar
# Data 3311 written to file
# Processing Michael Harrison
# Data 3312 written to file
# Processing Jill Balcon
# Data 3313 written to file
# Processing Peter Fettes
# Data 3314 written to file
# Processing Frederick Grisewood
# Data 3315 written to file
# Processing Mabel Constanduros
# Data 3316 written to file
# Processing Wing Guy Gibson VC DSO DFC
# Data 3317 written to file
# Processing Ralph Reader
# Data 3318 written to file
# Processing Pamela Frankau
# Data 3319 written to file
# Processing Alan Dent
# Data 3320 written to file
# Processing Charles Hill
# Data 3321 written to file
# Processing J B Morton
# Data 3322 written to file
# Processing C H Middleton
# Data 3323 written to file
# Processing Stephen Tallents
# Data 3324 written to file
# Processing Lady Eleanor Smith
# Data 3325 written to file
# Processing Tom Harrisson
# Data 3326 written to file
# Processing Ivor Brown
# Data 3327 written to file
# Processing C A Lejeune
# Data 3328 written to file
# Processing Herbert Hodge
# Data 3329 written to file
# Processing Beverley Baxter
# Data 3330 written to file
# Processing Frank Swinnerton
# Data 3331 written to file
# Processing Tom Driberg
# Data 3332 written to file
# Processing Ian Hay
# Data 3333 written to file
# Processing Donald McCullough
# Data 3334 written to file
# Processing Admiral Edward Evans
# Data 3335 written to file
# Processing Michael Powell
# Data 3336 written to file
# Processing Jonah Barrington
# Data 3337 written to file
# Processing Richard Tauber
# Data 3338 written to file
# Processing Lord Elton
# Data 3339 written to file
# Processing Emlyn Williams
# Data 3340 written to file
# Processing Barrington Dalby
# Data 3341 written to file
# Processing Nathaniel Gubbins
# Data 3342 written to file
# Processing Leslie Howard
# Data 3343 written to file
# Processing Beatrice Lillie
# Data 3344 written to file
# Processing Roy Plomley
# Data 3345 written to file
# Processing Ivor Novello
# Data 3346 written to file
# Processing Tom Webster
# Data 3347 written to file
# Processing Harry Parry
# Data 3348 written to file
# Processing Dame Eva Turner
# Data 3349 written to file
# Processing Arthur Askey
# Data 3350 written to file
# Processing Reverend Canon W H Elliott
# Data 3351 written to file
# Processing Joan Jay
# Data 3352 written to file
# Processing Captain A E Dingle
# Data 3353 written to file
# Processing Jack Hylton
# Data 3354 written to file
# Processing Pat Kirkwood
# Data 3355 written to file
# Processing C B Cochran
# Data 3356 written to file
# Processing Campbell
# Data 3357 written to file
# Processing James Agate
# Data 3358 written to file
# Processing Vic Oliver
# Data 3359 written to file

# %% [markdown]
# ## Overview of the Wikipeople data

# %%
df_update = pd.read_json('wiki_data.json', lines = True)
df_update
# Out:
#                  guests  index  gender          career        birth  \
# 0                            0    None            None         None
# 1     Ronnie O'Sullivan      1    male     pool player  +1975-12-05
# 2        Sharon Peacock      2  female  microbiologist  +1959-03-24
# 3            Simon Pegg      3    male           actor  +1970-02-14
# 4        Peter Hennessy      4    male      politician  +1947-03-28
# ...                 ...    ...     ...             ...          ...
# 3355       Pat Kirkwood   3355    male        engineer  +1927-12-22
# 3356        C B Cochran   3356    None            None         None
# 3357           Campbell   3357      NA              NA           NA
# 3358        James Agate   3358    male      journalist  +1877-09-09
# 3359         Vic Oliver   3359    male           actor  +1898-07-08
#
#                        country
# 0                         None
# 1               United Kingdom
# 2                           NA
# 3               United Kingdom
# 4               United Kingdom
# ...                        ...
# 3355  United States of America
# 3356                      None
# 3357                        NA
# 3358            United Kingdom
# 3359           Austria-Hungary
#
# [3360 rows x 6 columns]

# %%
bbc_wiki = pd.merge(df, df_update.drop('guests', axis=1), on=["index"])

# %%
bbc_wiki
# Out:
#             time    duration book luxury favourite  availibility  number  \
# 0     2023-06-04  42 minutes  NaN    NaN       NaN         False       0
# 1     2023-05-28  35 minutes  NaN    NaN       NaN         False       0
# 2     2023-05-26  43 minutes  NaN    NaN       NaN         False       8
# 3     2023-05-19  44 minutes  NaN    NaN       NaN         False       8
# 4     2023-05-12  37 minutes  NaN    NaN       NaN         False       8
# ...          ...         ...  ...    ...       ...           ...     ...
# 3355  1942-02-26  30 minutes  NaN    NaN       NaN         False       7
# 3356  1942-02-19  30 minutes  NaN    NaN       NaN         False       8
# 3357  1942-02-12  30 minutes  NaN    NaN       NaN         False       8
# 3358  1942-02-05  30 minutes  NaN    NaN       NaN         False       7
# 3359  1942-01-29  30 minutes  NaN    NaN       NaN         False       7
#
#                                                  guests  \
# 0                                            04/06/2023
# 1                     Ronnie O'Sullivan, snooker player
# 2     Desert Island Discs - Professor Sharon Peacock...
# 3                                     Simon Pegg, actor
# 4                   Professor Peter Hennessy, historian
# ...                                                 ...
# 3355                                       Pat Kirkwood
# 3356                                        C B Cochran
# 3357                                 Commander Campbell
# 3358                                        James Agate
# 3359                                         Vic Oliver
#
#                                           links  index  year  \
# 0     https://www.bbc.co.uk/programmes/m001mly1      0  2023
# 1     https://www.bbc.co.uk/programmes/m001mc30      1  2023
# 2     https://www.bbc.co.uk/programmes/m001m4nx      2  2023
# 3     https://www.bbc.co.uk/programmes/m001ly7j      3  2023
# 4     https://www.bbc.co.uk/programmes/m001lr3k      4  2023
# ...                                         ...    ...   ...
# 3355  https://www.bbc.co.uk/programmes/p009y0n8   3355  1942
# 3356  https://www.bbc.co.uk/programmes/p009y0nd   3356  1942
# 3357  https://www.bbc.co.uk/programmes/p009y0nh   3357  1942
# 3358  https://www.bbc.co.uk/programmes/p009y0nl   3358  1942
# 3359  https://www.bbc.co.uk/programmes/p009y0nq   3359  1942
#
#                    name  gender          career        birth  \
# 0                          None            None         None
# 1     Ronnie O'Sullivan    male     pool player  +1975-12-05
# 2        Sharon Peacock  female  microbiologist  +1959-03-24
# 3            Simon Pegg    male           actor  +1970-02-14
# 4        Peter Hennessy    male      politician  +1947-03-28
# ...                 ...     ...             ...          ...
# 3355       Pat Kirkwood    male        engineer  +1927-12-22
# 3356        C B Cochran    None            None         None
# 3357           Campbell      NA              NA           NA
# 3358        James Agate    male      journalist  +1877-09-09
# 3359         Vic Oliver    male           actor  +1898-07-08
#
#                        country
# 0                         None
# 1               United Kingdom
# 2                           NA
# 3               United Kingdom
# 4               United Kingdom
# ...                        ...
# 3355  United States of America
# 3356                      None
# 3357                        NA
# 3358            United Kingdom
# 3359           Austria-Hungary
#
# [3360 rows x 16 columns]

# %%
# Remove the first case because this episode hasn't been broadcast
bbc_wiki = bbc_wiki.iloc[1: , : ]

# %%
bbc_wiki.to_csv("bbc_wiki.csv")
